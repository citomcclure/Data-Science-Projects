# %%
run src/preprocessing.py

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
from sklearn.linear_model import Lasso, Ridge
from sklearn.model_selection import train_test_split
from tqdm import tqdm 
from time import time

# %%
def sample_training_set(X_train, y_train, n_pcnt):
    n = X_train.shape[0]*n_pcnt//100
    return n, X_train[:n], y_train[:n]

def time_function_call(function_call):
    start = time()
    result = function_call
    execution_time = time() - start
    return result, execution_time

def run_model(model, model_name, n_pcnt, data, labels):

    X_train, X_test, y_train, y_test = train_test_split(data, labels, random_state=42)

    
    n, X_samp, y_samp = sample_training_set(X_train, y_train, n_pcnt)
    
    _, fit_time = time_function_call(
        model.fit(X_samp, y_samp))
    
    train_pred, train_pred_time = time_function_call(
        model.predict(X_samp))
    
    test_pred, test_pred_time = time_function_call(
        model.predict(X_test))    
    
    return {
            'model' : model, 
            'model_name' : model_name,
            'n_pcnt' : n_pcnt,
            'n' : n, 
            'rmse_train' : np.sqrt(mean_squared_error(y_samp, train_pred)),
            'rmse_test' : np.sqrt(mean_squared_error(y_test, test_pred)),
            'mae_train' : mean_absolute_error(y_samp, train_pred),
            'mae_test' : mean_absolute_error(y_test, test_pred),
            'r2_train_score' : model.score(X_samp, y_samp),
            'r2_test_score' : model.score(X_test, y_test),
            'fit_time' : fit_time,
            'train_pred_time' : train_pred_time,
            'test_pred_time' : test_pred_time}

# %% [markdown]
# ## Variable Ranking - by Single Feature $R^2$ Score

# %%
test_scores = []
for feature in dataset_2.columns:
    results = run_model(Lasso(alpha=100), 'variable ranking', 50, dataset_2[[feature]], target_2) # running this on 
    # only one feature at a time
    test_score = results['r2_test_score']
    if test_score > 0.3:
        test_scores.append({'feature': feature, 'score' : test_score})

# %%
results = pd.DataFrame(test_scores).sort_values('score', ascending=False)
results.head(20)
# Out:
#         feature     score
# 5          PC 1  0.638048
# 4     GrLivArea  0.439422
# 2  GarageCars_3  0.396069
# 0  ExterQual_TA  0.364485
# 3    FirstFlrSF  0.360362
# 1    FullBath_1  0.330004

# %%
test_scores = []
for feature in dataset_4.columns:
    results = run_model(Lasso(), 'variable ranking', 50, dataset_4[[feature]], target_4)
    test_score = results['r2_test_score']
    if test_score > 0.2:
        test_scores.append({'feature': feature, 'score' : test_score})

# %%
results = pd.DataFrame(test_scores).sort_values('score', ascending=False)
results.head(20)
# Out:
#              feature     score
# 21              PC 1  0.529066
# 3          GrLivArea  0.439198
# 16      GarageCars_3  0.396864
# 12      ExterQual_TA  0.364821
# 2         FirstFlrSF  0.360158
# 9         FullBath_1  0.330278
# 0          YearBuilt  0.291891
# 17       BsmtQual_Ex  0.283994
# 5     KitchenQual_TA  0.279176
# 11  Foundation_PConc  0.276741
# 1       YearRemodAdd  0.275810
# 6         FullBath_2  0.256408
# 18    KitchenQual_Ex  0.255417
# 4        GarageYrBlt  0.244169
# 15  GarageFinish_Fin  0.228146
# 19      ExterQual_Ex  0.226715
# 13      ExterQual_Gd  0.218874
# 20     OverallQual_9  0.212312
# 14  BsmtFinType1_GLQ  0.207843
# 7       Fireplaces_0  0.203674

# %%
performant_features = pd.DataFrame()
performant_features['test_1'] = list(results.head(20).feature.values)
performant_features
# Out:
#               test_1
# 0               PC 1
# 1          GrLivArea
# 2       GarageCars_3
# 3       ExterQual_TA
# 4         FirstFlrSF
# 5         FullBath_1
# 6          YearBuilt
# 7        BsmtQual_Ex
# 8     KitchenQual_TA
# 9   Foundation_PConc
# 10      YearRemodAdd
# 11        FullBath_2
# 12    KitchenQual_Ex
# 13       GarageYrBlt
# 14  GarageFinish_Fin
# 15      ExterQual_Ex
# 16      ExterQual_Gd
# 17     OverallQual_9
# 18  BsmtFinType1_GLQ
# 19      Fireplaces_0

# %%
features_to_test = []
test_results = {}
for i, feature in enumerate(performant_features.test_1):
    features_to_test.append(feature)
    if i < 7: print(features_to_test)
    test_results[feature] = run_model(Lasso(), 'variable ranking', 100, dataset_4[features_to_test], target_4)
# Out:
# ['PC 1']
# ['PC 1', 'GrLivArea']
# ['PC 1', 'GrLivArea', 'GarageCars_3']
# ['PC 1', 'GrLivArea', 'GarageCars_3', 'ExterQual_TA']
# ['PC 1', 'GrLivArea', 'GarageCars_3', 'ExterQual_TA', 'FirstFlrSF']
# ['PC 1', 'GrLivArea', 'GarageCars_3', 'ExterQual_TA', 'FirstFlrSF', 'FullBath_1']
# ['PC 1', 'GrLivArea', 'GarageCars_3', 'ExterQual_TA', 'FirstFlrSF', 'FullBath_1', 'YearBuilt']

# %%
test_results = pd.DataFrame(test_results).T
test_results = test_results.loc[pd.Index(features_to_test)]
performant_features['test_1_r2'] = test_results.r2_test_score.values
test_results
# Out:
#                      fit_time mae_test mae_train  \
# PC 1              7.15256e-07  34411.9   36164.3
# GrLivArea         7.15256e-07  32250.7   33149.4
# GarageCars_3      7.15256e-07  27089.7   29580.2
# ExterQual_TA      1.19209e-06  27160.7   29481.6
# FirstFlrSF        7.15256e-07  24969.4   27802.6
# FullBath_1        7.15256e-07  25078.1   27634.4
# YearBuilt         4.76837e-07  24842.7   27247.7
# BsmtQual_Ex       1.19209e-06  24072.9   25286.6
# KitchenQual_TA    7.15256e-07  23973.1   25261.3
# Foundation_PConc  9.53674e-07    23870   25179.9
# YearRemodAdd      9.53674e-07  23985.6   24999.9
# FullBath_2        4.76837e-07  23174.9   24686.8
# KitchenQual_Ex    7.15256e-07  23007.8   23556.1
# GarageYrBlt       9.53674e-07  22845.2   23407.1
# GarageFinish_Fin  4.76837e-07  23028.1   23321.1
# ExterQual_Ex      4.76837e-07  22434.9   23088.2
# ExterQual_Gd      4.76837e-07  22613.6   22943.8
# OverallQual_9     4.76837e-07  22615.1   22914.8
# BsmtFinType1_GLQ  4.76837e-07  22397.7   22689.8
# Fireplaces_0      7.15256e-07  22456.6   22555.8
#
#                                                               model  \
# PC 1              Lasso(alpha=1.0, copy_X=True, fit_intercept=Tr...
# GrLivArea         Lasso(alpha=1.0, copy_X=True, fit_intercept=Tr...
# GarageCars_3      Lasso(alpha=1.0, copy_X=True, fit_intercept=Tr...
# ExterQual_TA      Lasso(alpha=1.0, copy_X=True, fit_intercept=Tr...
# FirstFlrSF        Lasso(alpha=1.0, copy_X=True, fit_intercept=Tr...
# FullBath_1        Lasso(alpha=1.0, copy_X=True, fit_intercept=Tr...
# YearBuilt         Lasso(alpha=1.0, copy_X=True, fit_intercept=Tr...
# BsmtQual_Ex       Lasso(alpha=1.0, copy_X=True, fit_intercept=Tr...
# KitchenQual_TA    Lasso(alpha=1.0, copy_X=True, fit_intercept=Tr...
# Foundation_PConc  Lasso(alpha=1.0, copy_X=True, fit_intercept=Tr...
# YearRemodAdd      Lasso(alpha=1.0, copy_X=True, fit_intercept=Tr...
# FullBath_2        Lasso(alpha=1.0, copy_X=True, fit_intercept=Tr...
# KitchenQual_Ex    Lasso(alpha=1.0, copy_X=True, fit_intercept=Tr...
# GarageYrBlt       Lasso(alpha=1.0, copy_X=True, fit_intercept=Tr...
# GarageFinish_Fin  Lasso(alpha=1.0, copy_X=True, fit_intercept=Tr...
# ExterQual_Ex      Lasso(alpha=1.0, copy_X=True, fit_intercept=Tr...
# ExterQual_Gd      Lasso(alpha=1.0, copy_X=True, fit_intercept=Tr...
# OverallQual_9     Lasso(alpha=1.0, copy_X=True, fit_intercept=Tr...
# BsmtFinType1_GLQ  Lasso(alpha=1.0, copy_X=True, fit_intercept=Tr...
# Fireplaces_0      Lasso(alpha=1.0, copy_X=True, fit_intercept=Tr...
#
#                         model_name     n n_pcnt r2_test_score r2_train_score  \
# PC 1              variable ranking  1083    100      0.524411       0.515181
# GrLivArea         variable ranking  1083    100      0.609907       0.649073
# GarageCars_3      variable ranking  1083    100      0.704973       0.717685
# ExterQual_TA      variable ranking  1083    100      0.708974       0.719097
# FirstFlrSF        variable ranking  1083    100       0.74056       0.744501
# FullBath_1        variable ranking  1083    100      0.742397       0.754655
# YearBuilt         variable ranking  1083    100      0.745128       0.759213
# BsmtQual_Ex       variable ranking  1083    100      0.771795       0.789344
# KitchenQual_TA    variable ranking  1083    100      0.774039       0.790125
# Foundation_PConc  variable ranking  1083    100      0.775191       0.790451
# YearRemodAdd      variable ranking  1083    100      0.775113       0.792222
# FullBath_2        variable ranking  1083    100       0.78864       0.805362
# KitchenQual_Ex    variable ranking  1083    100       0.79205        0.82535
# GarageYrBlt       variable ranking  1083    100      0.792951       0.827089
# GarageFinish_Fin  variable ranking  1083    100      0.793154       0.828118
# ExterQual_Ex      variable ranking  1083    100      0.806916       0.831478
# ExterQual_Gd      variable ranking  1083    100      0.805672       0.833068
# OverallQual_9     variable ranking  1083    100      0.806259       0.833166
# BsmtFinType1_GLQ  variable ranking  1083    100      0.810811       0.836794
# Fireplaces_0      variable ranking  1083    100      0.810902       0.837879
#
#                  rmse_test rmse_train test_pred_time train_pred_time
# PC 1               51428.1    56105.5    4.76837e-07     4.76837e-07
# GrLivArea          46576.7    47733.5    4.76837e-07     4.76837e-07
# GarageCars_3       40505.7    42813.6    4.76837e-07     4.76837e-07
# ExterQual_TA         40230    42706.5    9.53674e-07     7.15256e-07
# FirstFlrSF         37984.2    40729.6    4.76837e-07     4.76837e-07
# FullBath_1         37849.5      39912    4.76837e-07     4.76837e-07
# YearBuilt          37648.3    39539.6    2.38419e-07     4.76837e-07
# BsmtQual_Ex        35624.4      36983    4.76837e-07     7.15256e-07
# KitchenQual_TA     35448.8    36914.4    4.76837e-07     2.38419e-07
# Foundation_PConc   35358.3    36885.7    9.53674e-07     7.15256e-07
# YearRemodAdd       35364.4    36729.5    4.76837e-07     2.38419e-07
# FullBath_2         34284.4    35549.2    7.15256e-07     2.38419e-07
# KitchenQual_Ex     34006.7    33674.4    4.76837e-07     4.76837e-07
# GarageYrBlt          33933    33506.3    4.76837e-07     2.38419e-07
# GarageFinish_Fin   33916.3    33406.5    2.38419e-07     7.15256e-07
# ExterQual_Ex       32768.6    33078.3    2.38419e-07     7.15256e-07
# ExterQual_Gd         32874    32921.9    4.76837e-07     2.38419e-07
# OverallQual_9      32824.3    32912.3    4.76837e-07     7.15256e-07
# BsmtFinType1_GLQ   32436.4    32552.5    7.15256e-07     4.76837e-07
# Fireplaces_0       32428.6    32444.1    4.76837e-07     2.38419e-07

# %%
plt.plot(range(len(features_to_test)), test_results.loc[features_to_test].r2_test_score, label='test performance')
plt.plot(range(len(features_to_test)), test_results.loc[features_to_test].r2_train_score, label='train performance')
plt.legend()

# %% [markdown]
# ## Variable-Ranking - By Regression Coefficient in Full Model

# %%
results = run_model(Lasso(alpha=100), 'ridge', 100, dataset_2, target_2)

# %%
results
# Out:
# {'model': Lasso(alpha=100, copy_X=True, fit_intercept=True, max_iter=1000,
#     normalize=False, positive=False, precompute=False, random_state=None,
#     selection='cyclic', tol=0.0001, warm_start=False),
#  'model_name': 'ridge',
#  'n_pcnt': 100,
#  'n': 1083,
#  'rmse_train': 19977.732246662199,
#  'rmse_test': 26761.212837667805,
#  'mae_train': 13913.957495692423,
#  'mae_test': 16625.022862350936,
#  'r2_train_score': 0.93853022964574762,
#  'r2_test_score': 0.8712218649099126,
#  'fit_time': 1.430511474609375e-06,
#  'train_pred_time': 1.6689300537109375e-06,
#  'test_pred_time': 1.9073486328125e-06}

# %%
lasso_model = results['model']

# %%
coefficients = lasso_model.coef_
features = dataset_2.columns
coefficients = pd.Series(coefficients.T.ravel(), index=features)
coefficients.head()
# Out:
# MSSubClass_20   -0.0
# MSSubClass_30    0.0
# MSSubClass_40    0.0
# MSSubClass_45    0.0
# MSSubClass_50   -0.0
# dtype: float64

# %%
sorted_coefs = np.abs(coefficients).sort_values(ascending=False)
sorted_coefs.head(20)
# Out:
# OverallQual_10          96972.343777
# FullBath_3              45787.072269
# OverallQual_9           43241.048766
# RoofMatl_WdShngl        39109.640394
# TotRmsAbvGrd_12         31473.150273
# Neighborhood_NoRidge    31181.245682
# KitchenQual_Ex          24809.246945
# Neighborhood_Crawfor    21987.053651
# OverallQual_8           20238.202930
# GrLivArea               19029.840907
# Exterior1st_BrkFace     18818.981053
# Neighborhood_StoneBr    17932.756456
# BsmtQual_Ex             17046.346660
# BsmtExposure_Gd         15743.075031
# Functional_Typ          14675.640378
# OverallCond_3           14205.595871
# KitchenAbvGr_1          12416.984546
# TotRmsAbvGrd_10         11925.415857
# GarageCars_3             9920.084263
# GarageType_2Types        9740.079500
# dtype: float64

# %%
performant_features['test_2'] = list(list(sorted_coefs.head(20).index))
performant_features
# Out:
#               test_1 test_1_r2                test_2
# 0               PC 1  0.524411        OverallQual_10
# 1          GrLivArea  0.609907            FullBath_3
# 2       GarageCars_3  0.704973         OverallQual_9
# 3       ExterQual_TA  0.708974      RoofMatl_WdShngl
# 4         FirstFlrSF   0.74056       TotRmsAbvGrd_12
# 5         FullBath_1  0.742397  Neighborhood_NoRidge
# 6          YearBuilt  0.745128        KitchenQual_Ex
# 7        BsmtQual_Ex  0.771795  Neighborhood_Crawfor
# 8     KitchenQual_TA  0.774039         OverallQual_8
# 9   Foundation_PConc  0.775191             GrLivArea
# 10      YearRemodAdd  0.775113   Exterior1st_BrkFace
# 11        FullBath_2   0.78864  Neighborhood_StoneBr
# 12    KitchenQual_Ex   0.79205           BsmtQual_Ex
# 13       GarageYrBlt  0.792951       BsmtExposure_Gd
# 14  GarageFinish_Fin  0.793154        Functional_Typ
# 15      ExterQual_Ex  0.806916         OverallCond_3
# 16      ExterQual_Gd  0.805672        KitchenAbvGr_1
# 17     OverallQual_9  0.806259       TotRmsAbvGrd_10
# 18  BsmtFinType1_GLQ  0.810811          GarageCars_3
# 19      Fireplaces_0  0.810902     GarageType_2Types

# %%
features_to_test = []
test_results = {}
for feature in performant_features.test_2:
    print(dataset_2[features_to_test].shape)
    features_to_test.append(feature)
    test_results[feature] = run_model(Lasso(alpha=100), 'lasso', 100,
                                      dataset_2[features_to_test],
                                      target_2)
# Out:
# (1444, 0)
# (1444, 1)
# (1444, 2)
# (1444, 3)
# (1444, 4)
# (1444, 5)
# (1444, 6)
# (1444, 7)
# (1444, 8)
# (1444, 9)
# (1444, 10)
# (1444, 11)
# (1444, 12)
# (1444, 13)
# (1444, 14)
# (1444, 15)
# (1444, 16)
# (1444, 17)
# (1444, 18)
# (1444, 19)

# %%
test_results = pd.DataFrame(test_results).T
test_results = test_results.loc[features_to_test]
performant_features['test_2_r2'] = test_results.r2_test_score.values

plt.plot(range(len(features_to_test)), test_results.r2_test_score, label='test performance')
plt.plot(range(len(features_to_test)), test_results.r2_train_score, label='train performance')
plt.legend()

# %%
performant_features
# Out:
#               test_1 test_1_r2                test_2  test_2_r2
# 0               PC 1  0.524411        OverallQual_10  0.0947046
# 1          GrLivArea  0.609907            FullBath_3   0.109537
# 2       GarageCars_3  0.704973         OverallQual_9   0.314819
# 3       ExterQual_TA  0.708974      RoofMatl_WdShngl   0.323926
# 4         FirstFlrSF   0.74056       TotRmsAbvGrd_12   0.311868
# 5         FullBath_1  0.742397  Neighborhood_NoRidge   0.375082
# 6          YearBuilt  0.745128        KitchenQual_Ex   0.407884
# 7        BsmtQual_Ex  0.771795  Neighborhood_Crawfor   0.405762
# 8     KitchenQual_TA  0.774039         OverallQual_8   0.538098
# 9   Foundation_PConc  0.775191             GrLivArea   0.695339
# 10      YearRemodAdd  0.775113   Exterior1st_BrkFace   0.695383
# 11        FullBath_2   0.78864  Neighborhood_StoneBr   0.699452
# 12    KitchenQual_Ex   0.79205           BsmtQual_Ex   0.716074
# 13       GarageYrBlt  0.792951       BsmtExposure_Gd   0.739555
# 14  GarageFinish_Fin  0.793154        Functional_Typ   0.754858
# 15      ExterQual_Ex  0.806916         OverallCond_3   0.755627
# 16      ExterQual_Gd  0.805672        KitchenAbvGr_1    0.77384
# 17     OverallQual_9  0.806259       TotRmsAbvGrd_10   0.773601
# 18  BsmtFinType1_GLQ  0.810811          GarageCars_3   0.781565
# 19      Fireplaces_0  0.810902     GarageType_2Types   0.781456

# %% [markdown]
# ### Variable-Ranking - By Information Gain in Full Model

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
simple_dtree_results = run_model(DecisionTreeRegressor(), 'dtree', 100,
                                 dataset_2,
                                 target_2)

# %%
simple_dtree_results
# Out:
# {'model': DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'),
#  'model_name': 'dtree',
#  'n_pcnt': 100,
#  'n': 1083,
#  'rmse_train': 0.0,
#  'rmse_test': 39854.026205614209,
#  'mae_train': 0.0,
#  'mae_test': 25624.049861495845,
#  'r2_train_score': 1.0,
#  'r2_test_score': 0.71438898578172971,
#  'fit_time': 1.1920928955078125e-06,
#  'train_pred_time': 1.6689300537109375e-06,
#  'test_pred_time': 1.1920928955078125e-06}

# %%
simple_decision_tree_model = simple_dtree_results['model']
feature_importances = simple_decision_tree_model.feature_importances_
features = dataset_2.columns
feature_importances = pd.Series(feature_importances.T.ravel(), index=features).sort_values(ascending=False)
feature_importances.head(20)
# Out:
# PC 1                    0.745435
# GrLivArea               0.087075
# BsmtQual_Ex             0.020488
# BsmtFinSF1              0.016003
# GarageArea              0.012201
# TotalBsmtSF             0.009408
# ScreenPorch             0.006661
# FirstFlrSF              0.006643
# LotArea                 0.005955
# KitchenQual_TA          0.005940
# BsmtUnfSF               0.004442
# PC 4                    0.004398
# Neighborhood_Crawfor    0.004072
# OverallQual_9           0.003332
# PC 2                    0.003259
# PC 7                    0.003058
# BsmtFinSF2              0.002894
# YrSold                  0.002886
# YearBuilt               0.002694
# PC 8                    0.002438
# dtype: float64

# %%
performant_features['test_3'] = feature_importances.head(20).index

# %%
performant_features
# Out:
#               test_1 test_1_r2                test_2  test_2_r2  \
# 0               PC 1  0.524411        OverallQual_10  0.0947046
# 1          GrLivArea  0.609907            FullBath_3   0.109537
# 2       GarageCars_3  0.704973         OverallQual_9   0.314819
# 3       ExterQual_TA  0.708974      RoofMatl_WdShngl   0.323926
# 4         FirstFlrSF   0.74056       TotRmsAbvGrd_12   0.311868
# 5         FullBath_1  0.742397  Neighborhood_NoRidge   0.375082
# 6          YearBuilt  0.745128        KitchenQual_Ex   0.407884
# 7        BsmtQual_Ex  0.771795  Neighborhood_Crawfor   0.405762
# 8     KitchenQual_TA  0.774039         OverallQual_8   0.538098
# 9   Foundation_PConc  0.775191             GrLivArea   0.695339
# 10      YearRemodAdd  0.775113   Exterior1st_BrkFace   0.695383
# 11        FullBath_2   0.78864  Neighborhood_StoneBr   0.699452
# 12    KitchenQual_Ex   0.79205           BsmtQual_Ex   0.716074
# 13       GarageYrBlt  0.792951       BsmtExposure_Gd   0.739555
# 14  GarageFinish_Fin  0.793154        Functional_Typ   0.754858
# 15      ExterQual_Ex  0.806916         OverallCond_3   0.755627
# 16      ExterQual_Gd  0.805672        KitchenAbvGr_1    0.77384
# 17     OverallQual_9  0.806259       TotRmsAbvGrd_10   0.773601
# 18  BsmtFinType1_GLQ  0.810811          GarageCars_3   0.781565
# 19      Fireplaces_0  0.810902     GarageType_2Types   0.781456
#
#                   test_3
# 0                   PC 1
# 1              GrLivArea
# 2            BsmtQual_Ex
# 3             BsmtFinSF1
# 4             GarageArea
# 5            TotalBsmtSF
# 6            ScreenPorch
# 7             FirstFlrSF
# 8                LotArea
# 9         KitchenQual_TA
# 10             BsmtUnfSF
# 11                  PC 4
# 12  Neighborhood_Crawfor
# 13         OverallQual_9
# 14                  PC 2
# 15                  PC 7
# 16            BsmtFinSF2
# 17                YrSold
# 18             YearBuilt
# 19                  PC 8

# %%
features_to_test = []
test_results = {}
for feature in performant_features.test_3:
    features_to_test.append(feature)
    test_results[feature] = run_model(DecisionTreeRegressor(), 'dtree', 100,
                                      dataset_2[features_to_test],
                                      target_2)

# %%
test_results = pd.DataFrame(test_results).T
test_results = test_results.loc[features_to_test]
performant_features['test_3_r2_dtree'] = test_results.r2_test_score.values

plt.plot(range(len(features_to_test)), test_results.r2_test_score, label='test performance')
plt.plot(range(len(features_to_test)), test_results.r2_train_score, label='train performance')
plt.legend()

# %%
features_to_test = []
test_results = {}
for feature in performant_features.test_3:
    features_to_test.append(feature)
    test_results[feature] = run_model(Lasso(), 'lasso', 100,
                                      dataset_2[features_to_test],
                                      target_2)

test_results = pd.DataFrame(test_results).T
test_results = test_results.loc[features_to_test]
performant_features['test_3_r2_lasso'] = test_results.r2_test_score.values

plt.plot(range(len(features_to_test)), test_results.r2_test_score, label='test performance')
plt.plot(range(len(features_to_test)), test_results.r2_train_score, label='train performance')
plt.legend()

# %%
performant_features
# Out:
#               test_1 test_1_r2                test_2  test_2_r2  \
# 0               PC 1  0.524411        OverallQual_10  0.0947046
# 1          GrLivArea  0.609907            FullBath_3   0.109537
# 2       GarageCars_3  0.704973         OverallQual_9   0.314819
# 3       ExterQual_TA  0.708974      RoofMatl_WdShngl   0.323926
# 4         FirstFlrSF   0.74056       TotRmsAbvGrd_12   0.311868
# 5         FullBath_1  0.742397  Neighborhood_NoRidge   0.375082
# 6          YearBuilt  0.745128        KitchenQual_Ex   0.407884
# 7        BsmtQual_Ex  0.771795  Neighborhood_Crawfor   0.405762
# 8     KitchenQual_TA  0.774039         OverallQual_8   0.538098
# 9   Foundation_PConc  0.775191             GrLivArea   0.695339
# 10      YearRemodAdd  0.775113   Exterior1st_BrkFace   0.695383
# 11        FullBath_2   0.78864  Neighborhood_StoneBr   0.699452
# 12    KitchenQual_Ex   0.79205           BsmtQual_Ex   0.716074
# 13       GarageYrBlt  0.792951       BsmtExposure_Gd   0.739555
# 14  GarageFinish_Fin  0.793154        Functional_Typ   0.754858
# 15      ExterQual_Ex  0.806916         OverallCond_3   0.755627
# 16      ExterQual_Gd  0.805672        KitchenAbvGr_1    0.77384
# 17     OverallQual_9  0.806259       TotRmsAbvGrd_10   0.773601
# 18  BsmtFinType1_GLQ  0.810811          GarageCars_3   0.781565
# 19      Fireplaces_0  0.810902     GarageType_2Types   0.781456
#
#                   test_3 test_3_r2_dtree test_3_r2_lasso
# 0                   PC 1        0.564312        0.635541
# 1              GrLivArea         0.67382        0.662442
# 2            BsmtQual_Ex        0.699167        0.721865
# 3             BsmtFinSF1        0.713177        0.733308
# 4             GarageArea        0.738936        0.733342
# 5            TotalBsmtSF        0.703629        0.733343
# 6            ScreenPorch        0.676918        0.735511
# 7             FirstFlrSF        0.670172        0.736267
# 8                LotArea        0.687744        0.732015
# 9         KitchenQual_TA        0.700164        0.750488
# 10             BsmtUnfSF        0.723412        0.746097
# 11                  PC 4         0.73443        0.746493
# 12  Neighborhood_Crawfor         0.73695        0.747718
# 13         OverallQual_9        0.723271        0.761613
# 14                  PC 2        0.727178        0.763158
# 15                  PC 7        0.735154         0.76316
# 16            BsmtFinSF2        0.731021        0.762772
# 17                YrSold        0.731226        0.762255
# 18             YearBuilt        0.711748        0.765395
# 19                  PC 8        0.709656        0.765505
